# %% [markdown]
# # Quantum Tridiagonal Matrix Solver
#
# This is a quantum tridiagonal matrix solver.

# %%
# Import the relevant libraries etc.

import cirq
from cirq.contrib.svg import SVGCircuit

import sympy

# %%
# Set up the problem

a = 1
b = 2

# Eigenvalue register size
n_l = 3

# Problem Size
n_b = 1

# Number of Trotter Steps
m = 1

# %%
# Set up the registers

# Ancilla Qubit
anc = cirq.LineQubit(0)

# Eigenvalue register
q_l = []
for q in range(1,n_l + 1):
    q_l.append(cirq.LineQubit(q))
    
    
# Eigenvalue register
q_b = []
for q in range(n_l + 1,n_b + n_l + 1):
    q_b.append(cirq.LineQubit(q))



# Create the empty circuit
HHL_Circuit = cirq.Circuit()

# %%
# Check to see if all the qubits have been assigned to the correct registers
print(anc)
print(q_l)
print(q_b)
# Out:
# 0
# [cirq.LineQubit(1), cirq.LineQubit(2), cirq.LineQubit(3)]
# [cirq.LineQubit(4), cirq.LineQubit(5), cirq.LineQubit(6), cirq.LineQubit(7)]

# %% [markdown]
# ---
#
# Now that we have created these qubits we will now start building the circuit of the algorithm
#
# The first step is to put the eignevalue register in superposition
#
# ---

# %%
for q in q_l:
    HHL_Circuit.append(cirq.H(q))
    
# Check to see if the operation has been performed successfully
SVGCircuit(HHL_Circuit)

# %% [markdown]
# ---
#
# Now we can start building up the Hamiltonian Simulation portion of the algorithm.
#
# ---
#
# ![image.png](attachment:image.png)
#
# ---
#
# ![image-2.png](attachment:image-2.png)
#
# ---
#
# ![image-3.png](attachment:image-3.png)
#
# ---
#
# ![image-4.png](attachment:image-4.png)
#
# Note: TYPO! The rotation is supposed to be an X rotation so that it matches the circuit below
#
# ![image-5.png](attachment:image-5.png)
#
# ---
#
#
# These must be implemented in the order
#
# ![image-6.png](attachment:image-6.png)
#
# ---
#
# Some details about the number of repetitions required of these pieces for the controlled eignevalue operations
#
# ![image-7.png](attachment:image-7.png)
#
# ---

# %%
# First we must loop over the eigenvalue bits
for l in reversed(range(n_l)):
    
    print(l)
    
    # Apply the first term, H1
    # The sequence of gates need not be repeated since the exponent can be taken into the Z gate
    HHL_Circuit.append([
        cirq.X(q_b[n_b-1]).controlled_by(q_l[l]),
        ((cirq.Z(q_b[n_b-1])**(sympy.Symbol('a')*sympy.Symbol('t')/sympy.pi)).controlled_by(q_l[l]))**(2**(n_l-1-l)),
        cirq.X(q_b[n_b-1]).controlled_by(q_l[l]),
        ((cirq.Z(q_b[n_b-1])**(sympy.Symbol('a')*sympy.Symbol('t')/sympy.pi)).controlled_by(q_l[l]))**(2**(n_l-1-l))
    ])
    
    print('Applied H1 to qubit {}'.format(l))
    
    # Apply the second term, a piece of H2
    HHL_Circuit.append(((cirq.X(q_b[n_b-1])**(2*sympy.Symbol('b')*sympy.Symbol('t')/sympy.pi/sympy.Symbol('m')/2)).controlled_by(q_l[l])))
    print('Applied H2_1 to qubit {}'.format(l))
    
    
    # This is the loop for the repetition part
    for i in range(2**(n_l-1-l)):
        for j in range(m):
            print('Repetition {},{}'.format(i,m))
            
            # Apply the third term, a piece of H2
            HHL_Circuit.append(((cirq.X(q_b[n_b-1])**(-2*sympy.Symbol('b')*sympy.Symbol('t')/sympy.pi/sympy.Symbol('m'))).controlled_by(q_l[l])))
            
            # Apply the fourth term, a piece of H3
            #HHL_Circuit.append()
    

    # Apply the fifth and last term, another piece of H2
    HHL_Circuit.append(((cirq.X(q_b[n_b-1])**(-2*sympy.Symbol('b')*sympy.Symbol('t')/sympy.pi/sympy.Symbol('m')/2)).controlled_by(q_l[l])))
    print('Applied H2_3 to qubit {}'.format(l))
    
    print(l)
# Out:
# 2
# Applied H1 to qubit 2
# Applied H2_1 to qubit 2
# Repetition 0,1
# Applied H2_3 to qubit 2
# 2
# 1
# Applied H1 to qubit 1
# Applied H2_1 to qubit 1
# Repetition 0,1
# Repetition 1,1
# Applied H2_3 to qubit 1
# 1
# 0
# Applied H1 to qubit 0
# Applied H2_1 to qubit 0
# Repetition 0,1
# Repetition 1,1
# Repetition 2,1
# Repetition 3,1
# Applied H2_3 to qubit 0
# 0

# %%
# Check if the Circuit has been implemented as expected
SVGCircuit(HHL_Circuit)

# %%
    # Now the loop part begins, here we apply the m trotterized pieces of H2 and H3 2^i times
    for i in range(2^(l+1)):
        for j in range(m):
            print('i = {}, m = {}, l = {}'.format(i,m,l))
            # Apply the third term, another piece of H2
            HHL_Circuit.append(((cirq.X(q_b[n_b-1])**(-2*sympy.Symbol('b')*sympy.Symbol('t')/sympy.pi/sympy.Symbol('m'))).controlled_by(q_l[l])))
            print('Applied H2_2 to qubit {}'.format(l))
    
        
            # Apply the fourth term, m trotterized pieces of H3
